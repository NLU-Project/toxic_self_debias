# %%
import os
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score

def get_scores(df, model, label_name='true_labels', pred_name='predictions', score_name='scores', binary=True):
    """
    calculate relevant statistics for measuring bias.
    
    df: contains predictions and true_labels
    Depending on the dataset df should also have associations of identity 
    related to the id which will be tied to the original index 'Unnamed: 0'
    
    model: name of the model
    
    binary: boolean for if its only binary toxicity
    """
    
    
    labels = df[label_name]#df['true_labels']
    predictions = df[pred_name]#df['predictions']
    scores = df[score_name]#df['scores']
    
    if binary:
        f1_avg = 'binary'
        recall_pos = recall_score(labels, predictions) #Not sure about how to use the threshold for these for now
        #recall_neg = recall_score(labels, predictions, pos_label=0) # Not sure about this 
        
    avg_scores = scores.mean()
    f1 = f1_score(y_true = labels, y_pred = predictions, average=f1_avg)
    
    auc_roc = roc_auc_score(labels, scores)
    
    metrics  = {'avg-scores': avg_scores,
                'f1': f1,
                'auc-roc': auc_roc,
                'recall_pos': recall_pos,  # FPR
               }
    #return [acc,f1, 1-recall_neg] Need to understand why they do 1- recall_neg before adding it
    return metrics

# %%
def load_result_csv(result_path, dataset_name, model_name, file_name):
    return pd.read_csv(os.path.join(result_path , dataset_name, model , file_name))

result_path = '/scratch/sbp354/DSGA1012/Final_Project/models'
dataset_name = 'civil_comments_0.5'
model_name = 'roberta-large'
file_start = 'finetune_civil_comments_0.5_challenge_'
file_end = '_results.csv'

df = load_result_csv(result_path, dataset_name, model_name, file_start + dataset_name + file_end)

# %%
civil = load_result_csv(result_path, dataset_name, model_name, file_name)
test = load_result_csv(result_path, dataset_name, model_name, file_start + dataset_name + file_end)
sum((civil == test).scores)/len(civil)
# Out:
# 1.0

# %%
dataset_names = ['bibifi', 'civil_comments_0.5', 'SBIC','founta']
model_names = ['bert-base-uncased', 'roberta-large']

results = {}

for dataset in dataset_names:
    for model in model_names:
        df = load_result_csv(result_path, dataset, model, file_start + dataset + file_end)
        scores = get_scores(df, model_name, True)
#         if dataset not in results:
#             results[dataset] = {model_name: scores}
#         else:
#             results[dataset] = 

# datasets = ['']
# for dat
#      if dataset_
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /state/partition1/job-18294104/ipykernel_1063261/222548730.py in <module>
#       6 for dataset in dataset_names:
#       7     for model in model_names:
# ----> 8         df = load_result_csv(result_path, dataset, model, file_start + dataset + file_end)
#       9         scores = get_scores(df, model_name, True)
#      10 #         if dataset not in results:
#
# /state/partition1/job-18294104/ipykernel_1063261/1590481017.py in load_result_csv(result_path, dataset_name, model_name, file_name)
#       1 def load_result_csv(result_path, dataset_name, model_name, file_name):
# ----> 2     return pd.read_csv(os.path.join(result_path , dataset_name, model , file_name))
#       3
#       4 result_path = '/scratch/sbp354/DSGA1012/Final_Project/models'
#       5 dataset_name = 'civil_comments_0.5'
#
# ...

# %%
for dataset in dataset_names:
    for model in model_names:
        df = load_result_csv(result_path, dataset, model, file_start + dataset + file_end)
        scores = get_scores(df, model_name, True)

# %%
os.path.join(result_path)
# Out:
# '/scratch/sbp354/DSGA1012/Final_Project/models'

# %%
paths = [os.path.join(result_path, 'civil_comments_0.5', 'bert-base-uncased', 'finetune_civil_comments_0.5_challenge_bibifi_results.csv'),
         os.path.join(result_path, 'civil_comments_0.5', 'roberta-large', 'finetune_civil_comments_0.5_challenge_bibifi_results.csv'),
         os.path.join(result_path, 'civil_comments_0.5', 'bert-base-uncased', 'finetune_civil_comments_0.5_challenge_civil_comments_0.5_results.csv'),
         os.path.join(result_path, 'civil_comments_0.5', 'roberta-large', 'finetune_civil_comments_0.5_challenge_civil_comments_0.5_results.csv'),
         os.path.join(result_path, 'civil_comments_0.5', 'bert-base-uncased', 'finetune_civil_comments_0.5_challenge_covert_comments_results.csv'),
         os.path.join(result_path, 'civil_comments_0.5', 'roberta-large', 'finetune_civil_comments_0.5_challenge_covert_comments_results.csv'),
         os.path.join(result_path, 'civil_comments_0.5', 'bert-base-uncased', 'finetune_civil_comments_0.5_challenge_SBIC_results.csv'),
         os.path.join(result_path, 'civil_comments_0.5', 'roberta-large', 'finetune_civil_comments_0.5_challenge_SBIC_results.csv'),
         ]

d = ['bibifi', 'bibifi', 'civil_comments_0.5', 'civil_comments_0.5','covert','covert','SBIC', 'SBIC']
m = ['bert-base-uncased', 'roberta-large', 'bert-base-uncased', 'roberta-large', 'bert-base-uncased', 'roberta-large', 'bert-base-uncased', 'roberta-large']

results = {'bibifi': {'bert-base-uncased': 0,
                     'roberta-large': 0},
           'civil_comments_0.5': {'bert-base-uncased': 0,
                     'roberta-large': 0},
           'covert': {'bert-base-uncased': 0,
                     'roberta-large': 0},
           'SBIC': {'bert-base-uncased': 0,
                     'roberta-large': 0},}

for d,m,p in zip(d,m,paths):
    df = pd.read_csv(p)
    scores = get_scores(df,m,True)
    results[d][m] = scores

# %%
civil_df = pd.DataFrame.from_dict({(i,j): results[i][j] 
                           for i in results.keys() 
                           for j in results[i].keys()},
                       orient='index')

# %%
paths = [os.path.join(result_path, 'founta', 'bert-base-uncased', 'finetune_founta_challenge_bibifi_results.csv'),
os.path.join(result_path, 'founta', 'roberta-large', 'finetune_founta_challenge_bibifi_results.csv'),
os.path.join(result_path, 'founta', 'bert-base-uncased', 'finetune_founta_challenge_covert_comments_results.csv'),
os.path.join(result_path, 'founta', 'roberta-large', 'finetune_founta_challenge_covert_comments_results.csv'),
os.path.join(result_path, 'founta', 'bert-base-uncased', 'finetune_founta_challenge_founta_results.csv'),
os.path.join(result_path, 'founta', 'roberta-large', 'finetune_founta_challenge_founta_results.csv'),
os.path.join(result_path, 'founta', 'bert-base-uncased', 'finetune_founta_challenge_SBIC_results.csv'),
os.path.join(result_path, 'founta', 'roberta-large', 'finetune_founta_challenge_SBIC_results.csv')]
            
d = ['bibifi', 'bibifi','covert','covert', 'founta', 'founta', 'SBIC', 'SBIC']
m = ['bert-base-uncased', 'roberta-large', 'bert-base-uncased', 'roberta-large','bert-base-uncased', 'roberta-large', 'bert-base-uncased', 'roberta-large', 'bert-base-uncased', 'roberta-large']

results = {'bibifi': {'bert-base-uncased': 0,
                     'roberta-large': 0},
           'covert': {'bert-base-uncased': 0,
                     'roberta-large': 0},
           'founta': {'bert-base-uncased': 0,
                     'roberta-large': 0},
           'SBIC': {'bert-base-uncased': 0,
                     'roberta-large': 0},}

for d,m,p in zip(d,m,paths):
    df = pd.read_csv(p)
    scores = get_scores(df,m,True)
    results[d][m] = scores

founta_df = pd.DataFrame.from_dict({(i,j): results[i][j] 
                           for i in results.keys() 
                           for j in results[i].keys()},
                       orient='index')

# %%
pd.concat([civil_df, founta_df]).round(3)
# Out:
#                                       avg-scores     f1  auc-roc  recall_pos
# bibifi             bert-base-uncased       0.996  0.361    0.178       0.232
#                    roberta-large           0.959  0.430    0.270       0.393
# civil_comments_0.5 bert-base-uncased       0.989  0.635    0.093       0.524
#                    roberta-large           0.947  0.581    0.103       0.802
# covert             bert-base-uncased       0.971  0.034    0.462       0.018
#                    roberta-large           0.904  0.275    0.457       0.255
# SBIC               bert-base-uncased       0.962  0.417    0.264       0.296
#                    roberta-large           0.785  0.683    0.281       0.628
# bibifi             bert-base-uncased       0.973  0.520    0.322       0.597
#                    roberta-large           0.998  0.450    0.218       0.310
# covert             bert-base-uncased       0.973  0.193    0.458       0.144
# ...

# %%
df_sbic['offensiveYN']
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4693    0
# 4694    0
# 4695    0
# 4696    0
# 4697    0
# Name: offensiveYN, Length: 4698, dtype: int64

# %%
df_sbic[df_sbic.perspective_score > .5]
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 1              1             1
# 3              3             3
# 5              5             5
# 9              9             9
# 11            11            11
# ...          ...           ...
# 4682        4682          4682
# 4683        4683          4683
# 4684        4684          4684
# 4693        4693          4693
# 4695        4695          4695
#
#                                                    post  intentYN  sexYN  \
# 1     \nAlex Jones & Mike Cernovich: "It's crazy how...         1      0
# 3      happy birthday #LittleRocketMan\nyou #DumbFuc...         1      0
# 5     " you dodge a bullet " &#128517; &#8220;@DaRea...         1      0
# 9     """Boys convince themselves they are a man by ...         1      1
# 11    """I am happy to report that drowning does kil...         0      0
# ...                                                 ...       ...    ...
# ...

# %%
path_data = '/scratch/sbp354/DSGA1012/Final_Project/data'
file_names = ['PAPI_BiBiFi_test_evaluated.csv', 'PAPI_civil_test_evaluated.csv', 'PAPI_covert_test_evaluated.csv','PAPI_founta_test_evaluated.csv','PAPI_sbic_test_agg_evaluated.csv']

df_sbic = pd.read_csv(os.path.join(path_data,file))
df_sbic['pred'] = df_sbic[df_sbic.perspective_score > .5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /ext3/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /ext3/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /ext3/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pred'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_sbic["offensiveYN"]
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4693    0
# 4694    0
# 4695    0
# 4696    0
# 4697    0
# Name: offensiveYN, Length: 4698, dtype: int64

# %%
df_sbic["pred"]=np.where(((df_sbic["offensiveYN"].isin([0,0.5])) & (train["y"].isin([-19268905.6133,-19268905.6132])),1,0)

# %%
df_sbic[df_sbic.perspective_score > .5]
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 1              1             1
# 3              3             3
# 5              5             5
# 9              9             9
# 11            11            11
# ...          ...           ...
# 4682        4682          4682
# 4683        4683          4683
# 4684        4684          4684
# 4693        4693          4693
# 4695        4695          4695
#
#                                                    post  intentYN  sexYN  \
# 1     \nAlex Jones & Mike Cernovich: "It's crazy how...         1      0
# 3      happy birthday #LittleRocketMan\nyou #DumbFuc...         1      0
# 5     " you dodge a bullet " &#128517; &#8220;@DaRea...         1      0
# 9     """Boys convince themselves they are a man by ...         1      1
# 11    """I am happy to report that drowning does kil...         0      0
# ...                                                 ...       ...    ...
# ...

# %%
df_sbic
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 4693        4693          4693
# 4694        4694          4694
# 4695        4695          4695
# 4696        4696          4696
# 4697        4697          4697
#
#                                                    post  intentYN  sexYN  \
# 0     \n if you make a fact filled book or book of l...         1      0
# 1     \nAlex Jones & Mike Cernovich: "It's crazy how...         1      0
# 2      \nJason Donner‏:\n\nFBI Deputy Director Andre...         0      0
# 3      happy birthday #LittleRocketMan\nyou #DumbFuc...         1      0
# 4     " is your name kim jong - un , m'boy ? " " no ...         0      0
# ...                                                 ...       ...    ...
# ...

# %%
get_scores(df_sbic,'PAPI','offensiveYN',
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 4693        4693          4693
# 4694        4694          4694
# 4695        4695          4695
# 4696        4696          4696
# 4697        4697          4697
#
#                                                    post  intentYN  sexYN  \
# 0     \n if you make a fact filled book or book of l...         1      0
# 1     \nAlex Jones & Mike Cernovich: "It's crazy how...         1      0
# 2      \nJason Donner‏:\n\nFBI Deputy Director Andre...         0      0
# 3      happy birthday #LittleRocketMan\nyou #DumbFuc...         1      0
# 4     " is your name kim jong - un , m'boy ? " " no ...         0      0
# ...                                                 ...       ...    ...
# ...
